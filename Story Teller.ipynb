# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer
import torch

# Load GPT2 model & tokenizer
print("Loading model...")
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")
model.eval()
print("Model loaded!")

# Generate story from prompt
def generate_story(prompt, max_length=150):
    inputs = tokenizer.encode(prompt, return_tensors='pt')
    with torch.no_grad():
        outputs = model.generate(
            inputs,
            max_length=max_length,
            do_sample=True,
            top_k=50,
            top_p=0.95,
            temperature=0.9,
            num_return_sequences=1,
            pad_token_id=tokenizer.eos_token_id
        )
    story = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return story[len(prompt):]

# Chat loop
def chat():
    print("\n🤖 Hello! I'm your storytelling companion.")
    print("📖 Tell me the kind of story you want (fantasy, sci-fi, horror...)")

    while True:
        user_input = input("\nYou: ")
        if user_input.lower() in ['exit', 'quit']:
            print("Goodbye! Come back for more stories!")
            break
        print("\nLet me think...")
        story = generate_story(user_input)
        print(f"\n{story.strip()}")

# Start chatbot
if __name__ == "__main__":
    chat()
# Out:
# Loading model...
# Model loaded!
#
# 🤖 Hello! I'm your storytelling companion.
# 📖 Tell me the kind of story you want (fantasy, sci-fi, horror...)
# You:  Romantic story
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Let me think...
#
# of the four sisters who became a star on the Hollywood stage in the early '60s. One of the most famous is Betty Ford, the granddaughter of Oscar Pistorius, and one of the most famous is Michael Jackson, the father of the current president of the United States.
#
#
# The most famous of the four sisters was Betty Ford, the granddaughter of Oscar Pistorius, and one of the most famous is Michael Jackson, the father of the current president of the United States. In 1961, James Bond's wife, Elizabeth, married the then-23-year-old and became the wife of the man who had married her. The film "Jupiter" was the first to feature the wife of the man who had married
# You:  exit
# Goodbye! Come back for more stories!
